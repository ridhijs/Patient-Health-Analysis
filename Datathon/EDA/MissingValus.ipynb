# %%
import pandas as pd
import re

from scipy.stats import chi2_contingency

# %%
df = pd.read_csv("./../Data/training_v2.csv")

# %% [markdown]
# # Columns Available

# %%
print(list(df.columns))
# Out:
# ['encounter_id', 'patient_id', 'hospital_id', 'hospital_death', 'age', 'bmi', 'elective_surgery', 'ethnicity', 'gender', 'height', 'hospital_admit_source', 'icu_admit_source', 'icu_id', 'icu_stay_type', 'icu_type', 'pre_icu_los_days', 'readmission_status', 'weight', 'albumin_apache', 'apache_2_diagnosis', 'apache_3j_diagnosis', 'apache_post_operative', 'arf_apache', 'bilirubin_apache', 'bun_apache', 'creatinine_apache', 'fio2_apache', 'gcs_eyes_apache', 'gcs_motor_apache', 'gcs_unable_apache', 'gcs_verbal_apache', 'glucose_apache', 'heart_rate_apache', 'hematocrit_apache', 'intubated_apache', 'map_apache', 'paco2_apache', 'paco2_for_ph_apache', 'pao2_apache', 'ph_apache', 'resprate_apache', 'sodium_apache', 'temp_apache', 'urineoutput_apache', 'ventilated_apache', 'wbc_apache', 'd1_diasbp_invasive_max', 'd1_diasbp_invasive_min', 'd1_diasbp_max', 'd1_diasbp_min', 'd1_diasbp_noninvasive_max', 'd1_diasbp_noninvasive_min', 'd1_heartrate_max', 'd1_heartrate_min', 'd1_mbp_invasive_max', 'd1_mbp_invasive_min', 'd1_mbp_max', 'd1_mbp_min', 'd1_mbp_noninvasive_max', 'd1_mbp_noninvasive_min', 'd1_resprate_max', 'd1_resprate_min', 'd1_spo2_max', 'd1_spo2_min', 'd1_sysbp_invasive_max', 'd1_sysbp_invasive_min', 'd1_sysbp_max', 'd1_sysbp_min', 'd1_sysbp_noninvasive_max', 'd1_sysbp_noninvasive_min', 'd1_temp_max', 'd1_temp_min', 'h1_diasbp_invasive_max', 'h1_diasbp_invasive_min', 'h1_diasbp_max', 'h1_diasbp_min', 'h1_diasbp_noninvasive_max', 'h1_diasbp_noninvasive_min', 'h1_heartrate_max', 'h1_heartrate_min', 'h1_mbp_invasive_max', 'h1_mbp_invasive_min', 'h1_mbp_max', 'h1_mbp_min', 'h1_mbp_noninvasive_max', 'h1_mbp_noninvasive_min', 'h1_resprate_max', 'h1_resprate_min', 'h1_spo2_max', 'h1_spo2_min', 'h1_sysbp_invasive_max', 'h1_sysbp_invasive_min', 'h1_sysbp_max', 'h1_sysbp_min', 'h1_sysbp_noninvasive_max', 'h1_sysbp_noninvasive_min', 'h1_temp_max', 'h1_temp_min', 'd1_albumin_max', 'd1_albumin_min', 'd1_bilirubin_max', 'd1_bilirubin_min', 'd1_bun_max', 'd1_bun_min', 'd1_calcium_max', 'd1_calcium_min', 'd1_creatinine_max', 'd1_creatinine_min', 'd1_glucose_max', 'd1_glucose_min', 'd1_hco3_max', 'd1_hco3_min', 'd1_hemaglobin_max', 'd1_hemaglobin_min', 'd1_hematocrit_max', 'd1_hematocrit_min', 'd1_inr_max', 'd1_inr_min', 'd1_lactate_max', 'd1_lactate_min', 'd1_platelets_max', 'd1_platelets_min', 'd1_potassium_max', 'd1_potassium_min', 'd1_sodium_max', 'd1_sodium_min', 'd1_wbc_max', 'd1_wbc_min', 'h1_albumin_max', 'h1_albumin_min', 'h1_bilirubin_max', 'h1_bilirubin_min', 'h1_bun_max', 'h1_bun_min', 'h1_calcium_max', 'h1_calcium_min', 'h1_creatinine_max', 'h1_creatinine_min', 'h1_glucose_max', 'h1_glucose_min', 'h1_hco3_max', 'h1_hco3_min', 'h1_hemaglobin_max', 'h1_hemaglobin_min', 'h1_hematocrit_max', 'h1_hematocrit_min', 'h1_inr_max', 'h1_inr_min', 'h1_lactate_max', 'h1_lactate_min', 'h1_platelets_max', 'h1_platelets_min', 'h1_potassium_max', 'h1_potassium_min', 'h1_sodium_max', 'h1_sodium_min', 'h1_wbc_max', 'h1_wbc_min', 'd1_arterial_pco2_max', 'd1_arterial_pco2_min', 'd1_arterial_ph_max', 'd1_arterial_ph_min', 'd1_arterial_po2_max', 'd1_arterial_po2_min', 'd1_pao2fio2ratio_max', 'd1_pao2fio2ratio_min', 'h1_arterial_pco2_max', 'h1_arterial_pco2_min', 'h1_arterial_ph_max', 'h1_arterial_ph_min', 'h1_arterial_po2_max', 'h1_arterial_po2_min', 'h1_pao2fio2ratio_max', 'h1_pao2fio2ratio_min', 'apache_4a_hospital_death_prob', 'apache_4a_icu_death_prob', 'aids', 'cirrhosis', 'diabetes_mellitus', 'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma', 'solid_tumor_with_metastasis', 'apache_3j_bodysystem', 'apache_2_bodysystem']

# %% [markdown]
# ## Columns that are not a reading

# %%
cols_notareading = [c for c in df.columns if len(re.findall("(min|max|apache)",  c)) == 0]
print(cols_notareading)
# Out:
# ['encounter_id', 'patient_id', 'hospital_id', 'hospital_death', 'age', 'bmi', 'elective_surgery', 'ethnicity', 'gender', 'height', 'hospital_admit_source', 'icu_admit_source', 'icu_id', 'icu_stay_type', 'icu_type', 'pre_icu_los_days', 'readmission_status', 'weight', 'aids', 'cirrhosis', 'diabetes_mellitus', 'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma', 'solid_tumor_with_metastasis']

# %%
cols_diseases = cols_notareading[cols_notareading.index("aids"):]
print(cols_diseases)
# Out:
# ['aids', 'cirrhosis', 'diabetes_mellitus', 'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma', 'solid_tumor_with_metastasis']

# %% [markdown]
# # Missing Values

# %% [markdown]
# These have more than 80 % missing values

# %%
nacounts = df.isna().sum()
cols_extmiss = list(nacounts[nacounts.sort_values() > df.shape[0]*0.8].index)
print(cols_extmiss)
# Out:
# ['h1_diasbp_invasive_max', 'h1_diasbp_invasive_min', 'h1_mbp_invasive_max', 'h1_mbp_invasive_min', 'h1_sysbp_invasive_max', 'h1_sysbp_invasive_min', 'h1_albumin_max', 'h1_albumin_min', 'h1_bilirubin_max', 'h1_bilirubin_min', 'h1_bun_max', 'h1_bun_min', 'h1_calcium_max', 'h1_calcium_min', 'h1_creatinine_max', 'h1_creatinine_min', 'h1_hco3_max', 'h1_hco3_min', 'h1_hematocrit_max', 'h1_hematocrit_min', 'h1_lactate_max', 'h1_lactate_min', 'h1_platelets_max', 'h1_platelets_min', 'h1_wbc_max', 'h1_wbc_min', 'h1_arterial_pco2_max', 'h1_arterial_pco2_min', 'h1_arterial_ph_max', 'h1_arterial_ph_min', 'h1_arterial_po2_max', 'h1_arterial_po2_min', 'h1_pao2fio2ratio_max', 'h1_pao2fio2ratio_min']

# %%
kdf = df
for cold in cols_diseases:
    for colmiss in cols_extmiss:
        ct = pd.crosstab(kdf[cold] , kdf[colmiss].isna())
        c2t = chi2_contingency(ct)
        if c2t[1] < 0.01:
            print(f"{cold} : {colmiss} : {c2t[1]}")
        print("\n\n")
# Out:
# cirrhosis : h1_diasbp_invasive_max : 2.2492257743997913e-13
#
#
#
# cirrhosis : h1_diasbp_invasive_min : 2.2492257743997913e-13
#
#
#
# cirrhosis : h1_mbp_invasive_max : 1.5786887413968286e-12
#
#
#
# cirrhosis : h1_mbp_invasive_min : 1.5786887413968286e-12
#
#
#
# cirrhosis : h1_sysbp_invasive_max : 2.0587711748322757e-13
#
#
#
# cirrhosis : h1_sysbp_invasive_min : 2.0587711748322757e-13
#
#
#
# cirrhosis : h1_albumin_max : 2.640787310946045e-10
#
#
#
# cirrhosis : h1_albumin_min : 2.640787310946045e-10
#
#
#
# cirrhosis : h1_bilirubin_max : 1.7628890249097542e-13
#
#
#
# cirrhosis : h1_bilirubin_min : 1.7628890249097542e-13
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cirrhosis : h1_hematocrit_max : 0.0013054538313660008
#
#
#
# cirrhosis : h1_hematocrit_min : 0.0013054538313660008
#
#
#
# cirrhosis : h1_lactate_max : 4.900302801784983e-07
#
#
#
# cirrhosis : h1_lactate_min : 4.900302801784983e-07
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cirrhosis : h1_pao2fio2ratio_max : 0.004714608425941657
#
#
#
# cirrhosis : h1_pao2fio2ratio_min : 0.004714608425941657
#
#
#
# diabetes_mellitus : h1_diasbp_invasive_max : 0.000444134767736089
#
#
#
# diabetes_mellitus : h1_diasbp_invasive_min : 0.000444134767736089
#
#
#
# diabetes_mellitus : h1_mbp_invasive_max : 0.00019686118644631327
#
#
#
# diabetes_mellitus : h1_mbp_invasive_min : 0.00019686118644631327
#
#
#
# diabetes_mellitus : h1_sysbp_invasive_max : 0.00037971482730872155
#
#
#
# diabetes_mellitus : h1_sysbp_invasive_min : 0.00037971482730872155
#
#
#
# diabetes_mellitus : h1_albumin_max : 0.0039164239382530825
#
#
#
# diabetes_mellitus : h1_albumin_min : 0.0039164239382530825
#
#
#
#
#
#
#
#
#
# diabetes_mellitus : h1_bun_max : 2.5201852335884173e-38
#
#
#
# diabetes_mellitus : h1_bun_min : 2.5201852335884173e-38
#
#
#
# diabetes_mellitus : h1_calcium_max : 8.468982578337356e-42
#
#
#
# diabetes_mellitus : h1_calcium_min : 8.468982578337356e-42
#
#
#
# diabetes_mellitus : h1_creatinine_max : 3.054501844998934e-39
#
#
#
# diabetes_mellitus : h1_creatinine_min : 3.054501844998934e-39
#
#
#
# diabetes_mellitus : h1_hco3_max : 2.636221120283684e-29
#
#
#
# diabetes_mellitus : h1_hco3_min : 2.636221120283684e-29
#
#
#
# diabetes_mellitus : h1_hematocrit_max : 8.29765531448976e-05
#
#
#
# diabetes_mellitus : h1_hematocrit_min : 8.29765531448976e-05
#
#
#
# diabetes_mellitus : h1_lactate_max : 5.3678955092558635e-08
#
#
#
# diabetes_mellitus : h1_lactate_min : 5.3678955092558635e-08
#
#
#
# diabetes_mellitus : h1_platelets_max : 6.386891743017386e-07
#
#
#
# diabetes_mellitus : h1_platelets_min : 6.386891743017386e-07
#
#
#
# diabetes_mellitus : h1_wbc_max : 2.261847773366594e-05
#
#
#
# diabetes_mellitus : h1_wbc_min : 2.261847773366594e-05
#
#
#
# diabetes_mellitus : h1_arterial_pco2_max : 6.827155507979429e-14
#
#
#
# diabetes_mellitus : h1_arterial_pco2_min : 6.827155507979429e-14
#
#
#
# diabetes_mellitus : h1_arterial_ph_max : 6.363642602197374e-13
#
#
#
# diabetes_mellitus : h1_arterial_ph_min : 6.363642602197374e-13
#
#
#
# diabetes_mellitus : h1_arterial_po2_max : 1.3492976164398043e-13
#
#
#
# diabetes_mellitus : h1_arterial_po2_min : 1.3492976164398043e-13
#
#
#
# diabetes_mellitus : h1_pao2fio2ratio_max : 3.5335218963472666e-09
#
#
#
# diabetes_mellitus : h1_pao2fio2ratio_min : 3.5335218963472666e-09
#
#
#
# hepatic_failure : h1_diasbp_invasive_max : 3.290119454201859e-14
#
#
#
# hepatic_failure : h1_diasbp_invasive_min : 3.290119454201859e-14
#
#
#
# hepatic_failure : h1_mbp_invasive_max : 1.923883401558894e-14
#
#
#
# hepatic_failure : h1_mbp_invasive_min : 1.923883401558894e-14
#
#
#
# hepatic_failure : h1_sysbp_invasive_max : 3.03440915183557e-14
#
#
#
# hepatic_failure : h1_sysbp_invasive_min : 3.03440915183557e-14
#
#
#
# hepatic_failure : h1_albumin_max : 6.583361465261354e-07
#
#
#
# hepatic_failure : h1_albumin_min : 6.583361465261354e-07
#
#
#
# hepatic_failure : h1_bilirubin_max : 3.5937562298862058e-09
#
#
#
# hepatic_failure : h1_bilirubin_min : 3.5937562298862058e-09
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hepatic_failure : h1_lactate_max : 4.2793979875738226e-10
#
#
#
# hepatic_failure : h1_lactate_min : 4.2793979875738226e-10
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hepatic_failure : h1_pao2fio2ratio_max : 0.005895880428298061
#
#
#
# hepatic_failure : h1_pao2fio2ratio_min : 0.005895880428298061
#
#
#
# immunosuppression : h1_diasbp_invasive_max : 4.182299252974087e-08
#
#
#
# immunosuppression : h1_diasbp_invasive_min : 4.182299252974087e-08
#
#
#
# immunosuppression : h1_mbp_invasive_max : 4.258524119552278e-07
#
#
#
# immunosuppression : h1_mbp_invasive_min : 4.258524119552278e-07
#
#
#
# immunosuppression : h1_sysbp_invasive_max : 3.8072049658185923e-08
#
#
#
# immunosuppression : h1_sysbp_invasive_min : 3.8072049658185923e-08
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# immunosuppression : h1_lactate_max : 1.0013067074891258e-08
#
#
#
# immunosuppression : h1_lactate_min : 1.0013067074891258e-08
#
#
#
#
#
#
#
#
#
# immunosuppression : h1_wbc_max : 0.00925800690096127
#
#
#
# immunosuppression : h1_wbc_min : 0.00925800690096127
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# leukemia : h1_diasbp_invasive_max : 5.532137325151811e-05
#
#
#
# leukemia : h1_diasbp_invasive_min : 5.532137325151811e-05
#
#
#
# leukemia : h1_mbp_invasive_max : 2.8143379725567733e-05
#
#
#
# leukemia : h1_mbp_invasive_min : 2.8143379725567733e-05
#
#
#
# leukemia : h1_sysbp_invasive_max : 5.342810321266601e-05
#
#
#
# leukemia : h1_sysbp_invasive_min : 5.342810321266601e-05
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# leukemia : h1_lactate_max : 0.0021700155051664846
#
#
#
# leukemia : h1_lactate_min : 0.0021700155051664846
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lymphoma : h1_diasbp_invasive_max : 0.009366059566901647
#
#
#
# lymphoma : h1_diasbp_invasive_min : 0.009366059566901647
#
#
#
#
#
#
#
#
#
# lymphoma : h1_sysbp_invasive_max : 0.00919327438272883
#
#
#
# lymphoma : h1_sysbp_invasive_min : 0.00919327438272883
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# solid_tumor_with_metastasis : h1_hematocrit_max : 0.007676461240750626
#
#
#
# solid_tumor_with_metastasis : h1_hematocrit_min : 0.007676461240750626
#
#
#
# solid_tumor_with_metastasis : h1_lactate_max : 0.003340682989682564
#
#
#
# solid_tumor_with_metastasis : h1_lactate_min : 0.003340682989682564
#
#
#
# solid_tumor_with_metastasis : h1_platelets_max : 0.00433311988974238
#
#
#
# solid_tumor_with_metastasis : h1_platelets_min : 0.00433311988974238
#
#
#
# solid_tumor_with_metastasis : h1_wbc_max : 0.0013963587813256308
#
#
#
# solid_tumor_with_metastasis : h1_wbc_min : 0.0013963587813256308
#
#
#
# solid_tumor_with_metastasis : h1_arterial_pco2_max : 0.0007198472260081003
#
#
#
# solid_tumor_with_metastasis : h1_arterial_pco2_min : 0.0007198472260081003
#
#
#
# solid_tumor_with_metastasis : h1_arterial_ph_max : 0.003910530444485024
#
#
#
# solid_tumor_with_metastasis : h1_arterial_ph_min : 0.003910530444485024
#
#
#
# solid_tumor_with_metastasis : h1_arterial_po2_max : 0.0010564149810509628
#
#
#
# solid_tumor_with_metastasis : h1_arterial_po2_min : 0.0010564149810509628

# %%
df[extmiss + ["hospital_death"]]
# Out:
#        h1_diasbp_invasive_max  h1_diasbp_invasive_min  h1_mbp_invasive_max  \
# 0                         NaN                     NaN                  NaN
# 1                         NaN                     NaN                  NaN
# 2                         NaN                     NaN                  NaN
# 3                        62.0                    44.0                 92.0
# 4                         NaN                     NaN                  NaN
# ...                       ...                     ...                  ...
# 91708                     NaN                     NaN                  NaN
# 91709                     NaN                     NaN                  NaN
# 91710                     NaN                     NaN                  NaN
# 91711                     NaN                     NaN                  NaN
# 91712                     NaN                     NaN                  NaN
#
#        h1_mbp_invasive_min  h1_sysbp_invasive_max  h1_sysbp_invasive_min  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                     71.0                  136.0                  106.0
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 91708                  NaN                    NaN                    NaN
# 91709                  NaN                    NaN                    NaN
# 91710                  NaN                    NaN                    NaN
# 91711                  NaN                    NaN                    NaN
# 91712                  NaN                    NaN                    NaN
#
#        h1_albumin_max  h1_albumin_min  h1_bilirubin_max  h1_bilirubin_min  \
# 0                 NaN             NaN               NaN               NaN
# 1                 NaN             NaN               NaN               NaN
# 2                 NaN             NaN               NaN               NaN
# 3                 NaN             NaN               NaN               NaN
# 4                 NaN             NaN               NaN               NaN
# ...               ...             ...               ...               ...
# 91708             NaN             NaN               NaN               NaN
# 91709             NaN             NaN               NaN               NaN
# 91710             NaN             NaN               NaN               NaN
# 91711             NaN             NaN               NaN               NaN
# 91712             NaN             NaN               NaN               NaN
#
#        ...  h1_wbc_min  h1_arterial_pco2_max  h1_arterial_pco2_min  \
# 0      ...         NaN                   NaN                   NaN
# 1      ...       12.70                  37.0                37.000
# 2      ...         NaN                   NaN                   NaN
# 3      ...        8.80                  36.0                33.000
# 4      ...         NaN                   NaN                   NaN
# ...    ...         ...                   ...                   ...
# 91708  ...        5.68                  48.0                48.000
# 91709  ...         NaN                   NaN                   NaN
# 91710  ...         NaN                  15.0                14.997
# 91711  ...         NaN                   NaN                   NaN
# 91712  ...         NaN                   NaN                   NaN
#
#        h1_arterial_ph_max  h1_arterial_ph_min  h1_arterial_po2_max  \
# 0                     NaN                 NaN                  NaN
# 1                    7.45                7.45                 51.0
# 2                     NaN                 NaN                  NaN
# 3                    7.37                7.34                337.0
# 4                     NaN                 NaN                  NaN
# ...                   ...                 ...                  ...
# 91708                7.34                7.34                144.0
# 91709                 NaN                 NaN                  NaN
# 91710                6.93                6.93                136.0
# 91711                 NaN                 NaN                  NaN
# 91712                 NaN                 NaN                  NaN
#
#        h1_arterial_po2_min  h1_pao2fio2ratio_max  h1_pao2fio2ratio_min  \
# 0                      NaN                   NaN                   NaN
# 1                     51.0                  51.0                  51.0
# 2                      NaN                   NaN                   NaN
# 3                    265.0                 337.0                 337.0
# 4                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 91708                144.0                   NaN                   NaN
# 91709                  NaN                   NaN                   NaN
# 91710                136.0                   NaN                   NaN
# 91711                  NaN                   NaN                   NaN
# 91712                  NaN                   NaN                   NaN
#
#        hospital_death
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 91708               0
# 91709               0
# 91710               0
# 91711               0
# 91712               0
#
# [91713 rows x 35 columns]
